# %% [markdown]
# just get the raw counts of the EPO cohort for subsequent TMM normalization in R.

# %%
import pandas as pd
import scanpy as sc
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns


hfont = {'fontname':'Helvetica'}
sns.set(font_scale = 2)
sns.set_style(style='white')


from scipy.stats import mannwhitneyu

np.random.seed(31)

# %%
"""
@returns passingSamps, counts df whose samples do not exceed 95th percentile
for any of the ribosomal read fraction, 3' bias, or intron/exon ratio
"""
def sampleQC(cts, intronPath, riboPath, prime3Path):
    intronExon = pd.read_csv(intronPath, sep = "\t", index_col = 0).dropna()
    riboFrac = pd.read_csv(riboPath, sep = ",", index_col = 0).dropna()
    threePrimeBias = pd.read_csv(prime3Path, sep = "\t", index_col = 0).dropna()
    
    # from mira
    ribo = 0.2 
    deg = 0.4
    intron = 3
    
    # DISCARD SAMPLES > THRESHOLDS
    discardIntron = intronExon[intronExon.iloc[:,0] > intron]
    discardRibo = riboFrac[riboFrac.iloc[:,0] > ribo]
    discardBias = threePrimeBias[threePrimeBias.iloc[:,0] > deg]

    bad = list(set(discardBias.index.tolist() + 
                   discardIntron.index.tolist() + discardRibo.index.tolist()))
   
    goodSamps = np.setdiff1d(cts.columns.tolist(), bad)

    passingSamps = cts[goodSamps]
    return(passingSamps)

# %%
def dropZeroGenes(df):
    return(df.loc[~(df==0).all(axis=1)])

# %%
msBase = "/Users/kayaneh/Documents/deconvolution/molecstetho/remapped_unstranded/"
molecStethoCtsPath = msBase + "htseq_merged_unstrandedTS3_molestetho.csv"
cts = pd.read_csv(molecStethoCtsPath, sep = ",", index_col = [0, 1])

intronPath = msBase + "intron_exon_ratios_unstrandedTS3_molestetho.txt"
riboPath = msBase + "molecStetho_ribo_frac_unstrandedTS3.txt"
prime3Path = msBase + "deg_3prime_bias_frac_1_unstrandedTS3_molestetho.txt"

# %%
intronExon = pd.read_csv(intronPath, sep = "\t", index_col = 0).dropna()
riboFrac = pd.read_csv(riboPath, sep = ",", index_col = 0).dropna()
threePrimeBias = pd.read_csv(prime3Path, sep = "\t", index_col = 0).dropna()

# %%
passingQCCounts = sampleQC(cts, intronPath, riboPath, prime3Path)

# %%
goodSamps = passingQCCounts.columns.tolist()

# %%
# subset the counts to the good samples
cts = cts[goodSamps]

# %%
cts.shape
# Out:
# (60721, 195)

# %% [markdown]
# # now lets do this based on study

# %%
shuMeta = pd.read_excel("/Users/kayaneh/Documents/deconvolution/molecstetho/Ibarra et al NC Sample Code.xlsx",
                       sheet_name = None)

# %%
srrMeta = pd.read_csv("/Users/kayaneh/Documents/deconvolution/molecstetho/SraRunTable.txt.csv",
                     sep = ",", index_col = 0)
srrMeta["Run"] = srrMeta.index.tolist()

# %%
shuMeta.keys()
# Out:
# dict_keys(['Healthy cont (plasma vs buffy)', 'Healthy cont (transcript type)', 'AML-MM patient samples overview', 'MM longitudial', 'AML longitudial', 'GCSF', 'EPO'])

# %% [markdown]
# # EPO only

# %%
# these are the CKD samples
epo = shuMeta['EPO']
epo = epo.iloc[1:,:]
epo.columns = epo.iloc[0,:]
epo = epo.iloc[:,1:]
epo.set_index("Day", inplace = True)
epo = epo.iloc[1:,:]
epo
# Out:
# 1                          0                   1                    2   \
# Day
# EPO1            3408_004-EPO1       3417_004-EPO1                  NaN
# EPO2            3492_004-EPO2       3502_004-EPO2                  NaN
# EPO3            3541_004-EPO3       3549_004-EPO3                  NaN
# EPO4            3693_004-EPO4       3702_004-EPO4                  NaN
# EPO5            6032_004-EPO5       6040_004-EPO5                  NaN
# EPO6            6215_004-EPO6       6293_004-EPO6                  NaN
# EPO7           11954_004-EPO7      12072_004-EPO7                  NaN
# EPO8           13340_004-EPO8      13421_004-EPO8                  NaN
# EPO9           14277_004-EPO9      14285_004-EPO9                  NaN
# Control 1  9495_010-Stability  9633_010-Stability  10045_010-Stability
# Control 2  9498_011-Stability  9637_011-Stability  10052_011-Stability
# Control 3  9503_013-Stability                 NaN                  NaN
#
# 1                           3               4              8              9   \
# Day
# EPO1             3446_004-EPO1             NaN            NaN            NaN
# EPO2                       NaN   3523_004-EPO2  3558_004-EPO2            NaN
# EPO3                       NaN   3570_004-EPO3  3684_004-EPO3            NaN
# EPO4             3795_004-EPO4             NaN            NaN  3810_004-EPO4
# EPO5             6081_004-EPO5             NaN            NaN  6300_004-EPO5
# EPO6             6417_004-EPO6             NaN            NaN  6584_004-EPO6
# EPO7            12098_004-EPO7             NaN            NaN            NaN
# EPO8                       NaN  13449_004-EPO8            NaN            NaN
# EPO9                       NaN  14302_004-EPO9            NaN            NaN
# Control 1  10086_010-Stability             NaN            NaN            NaN
# Control 2  10082_011-Stability             NaN            NaN            NaN
# Control 3                  NaN             NaN            NaN            NaN
#
# 1                      10              11             13              14  \
# Day
# EPO1        3533_004-EPO1             NaN            NaN             NaN
# EPO2                  NaN             NaN            NaN             NaN
# EPO3                  NaN             NaN            NaN             NaN
# EPO4                  NaN             NaN            NaN             NaN
# EPO5                  NaN             NaN  6551_004-EPO5             NaN
# EPO6                  NaN             NaN  6867_004-EPO6             NaN
# EPO7                  NaN             NaN            NaN  12517_004-EPO7
# EPO8                  NaN  13712_004-EPO8            NaN  13742_004-EPO8
# EPO9       14332_004-EPO9             NaN            NaN             NaN
# Control 1             NaN             NaN            NaN             NaN
# Control 2             NaN             NaN            NaN             NaN
# Control 3             NaN             NaN            NaN             NaN
#
# 1                      15              16              17              18  \
# Day
# EPO1                  NaN             NaN             NaN             NaN
# EPO2                  NaN             NaN             NaN             NaN
# EPO3                  NaN             NaN             NaN             NaN
# EPO4                  NaN             NaN             NaN             NaN
# EPO5        6574_004-EPO5             NaN             NaN             NaN
# EPO6                  NaN   6879_004-EPO6             NaN             NaN
# EPO7                  NaN  12570_004-EPO7             NaN             NaN
# EPO8                  NaN             NaN             NaN  13759_004-EPO8
# EPO9       14434_004-EPO9             NaN  14447_004-EPO9             NaN
# Control 1             NaN             NaN             NaN             NaN
# Control 2             NaN             NaN             NaN             NaN
# Control 3             NaN             NaN             NaN             NaN
#
# 1                      23              25              30              31  \
# Day
# EPO1                  NaN             NaN             NaN             NaN
# EPO2                  NaN             NaN             NaN             NaN
# EPO3                  NaN             NaN             NaN             NaN
# EPO4                  NaN             NaN             NaN             NaN
# EPO5                  NaN             NaN   6952_004-EPO5             NaN
# EPO6        6949_004-EPO6             NaN   6985_004-EPO6             NaN
# EPO7       13073_004-EPO7             NaN  13221_004-EPO7             NaN
# EPO8                  NaN  14186_004-EPO8             NaN             NaN
# EPO9       14476_004-EPO9             NaN             NaN  14552_004-EPO9
# Control 1             NaN             NaN             NaN             NaN
# Control 2             NaN             NaN             NaN             NaN
# Control 3             NaN             NaN             NaN             NaN
#
# 1                      32
# Day
# EPO1                  NaN
# EPO2                  NaN
# EPO3                  NaN
# EPO4                  NaN
# EPO5                  NaN
# EPO6                  NaN
# EPO7                  NaN
# EPO8       14270_004-EPO8
# EPO9                  NaN
# Control 1             NaN
# Control 2             NaN
# Control 3             NaN

# %%
patient = []
sampName = []
day = []
for pat in epo.index:
    sampsThisEPO = epo.loc[pat].dropna().to_frame()
    day += sampsThisEPO.index.tolist()
    sampName += sampsThisEPO.T.values.tolist()[0]
    patient += [pat] * sampsThisEPO.shape[0]

# %%
epoDF = pd.DataFrame(index = ["Patient", "Sample Name", "Day"],
            data = [patient, sampName, day]).T

# %%
srrID = []
for i in epoDF["Sample Name"]:
    srrID += srrMeta[srrMeta["Sample Name"] == i]["Run"].values.tolist()

# %%
epoDF["Run"] = srrID # add the SRA info to the data

# %% [markdown]
# subset the epoDF based on the samples passing QC

# %%
epoDF = epoDF[epoDF["Run"].isin(goodSamps)]

# %%
np.unique(epoDF['Sample Name'])
# Out:
# array(['10045_010-Stability', '10052_011-Stability',
#        '10082_011-Stability', '10086_010-Stability', '12072_004-EPO7',
#        '12098_004-EPO7', '12517_004-EPO7', '12570_004-EPO7',
#        '13221_004-EPO7', '13340_004-EPO8', '13421_004-EPO8',
#        '13449_004-EPO8', '13712_004-EPO8', '13742_004-EPO8',
#        '13759_004-EPO8', '14186_004-EPO8', '14270_004-EPO8',
#        '14277_004-EPO9', '14285_004-EPO9', '14302_004-EPO9',
#        '14332_004-EPO9', '14434_004-EPO9', '14476_004-EPO9',
#        '14552_004-EPO9', '3408_004-EPO1', '3417_004-EPO1',
#        '3446_004-EPO1', '3492_004-EPO2', '3502_004-EPO2', '3523_004-EPO2',
#        '3533_004-EPO1', '3541_004-EPO3', '3549_004-EPO3', '3558_004-EPO2',
#        '3570_004-EPO3', '3684_004-EPO3', '3693_004-EPO4', '3702_004-EPO4',
#        '3795_004-EPO4', '3810_004-EPO4', '6032_004-EPO5', '6040_004-EPO5',
#        '6081_004-EPO5', '6215_004-EPO6', '6293_004-EPO6', '6300_004-EPO5',
#        '6417_004-EPO6', '6551_004-EPO5', '6574_004-EPO5', '6584_004-EPO6',
#        '6867_004-EPO6', '6879_004-EPO6', '6949_004-EPO6', '6952_004-EPO5',
#        '6985_004-EPO6', '9495_010-Stability', '9498_011-Stability',
#        '9503_013-Stability', '9633_010-Stability', '9637_011-Stability'],
#       dtype=object)

# %%
"""epoDF.to_csv("/Users/kayaneh/Documents/deconvolution/molecstetho/remapped_unstranded/epoONLY_postQC_unstranded_intron3_09222021.csv",
            index = True, header = True)"""

# %%
epoCts_unstranded = cts[epoDF["Run"]]

# %%
epoCts_unstranded = epoCts_unstranded[epoCts_unstranded.any(axis = 1)]

# %%
epoCts_unstranded.shape
# Out:
# (24915, 60)

# %%
epoCts_unstranded
# Out:
#                                                SRR8492548  SRR8492550  \
# gene_name              gene_num
# TSPAN6                 ENSG00000000003                  5           8
# TNMD                   ENSG00000000005                  0           2
# DPM1                   ENSG00000000419                 57         202
# SCYL3                  ENSG00000000457                 42         128
# C1orf112               ENSG00000000460                 14          37
# ...                                                   ...         ...
# __no_feature           __no_feature                111506      257303
# __ambiguous            __ambiguous                  78384      182111
# __too_low_aQual        __too_low_aQual              27144       36791
# __not_aligned          __not_aligned               205118      618443
# __alignment_not_unique __alignment_not_unique      251976      643631
#
#                                                SRR8492552  SRR8492555  \
# gene_name              gene_num
# TSPAN6                 ENSG00000000003                  3          12
# TNMD                   ENSG00000000005                  3           0
# DPM1                   ENSG00000000419                 67         247
# SCYL3                  ENSG00000000457                 52         177
# C1orf112               ENSG00000000460                 10          65
# ...                                                   ...         ...
# __no_feature           __no_feature                181123      399021
# __ambiguous            __ambiguous                  98469      254913
# __too_low_aQual        __too_low_aQual              25176       63408
# __not_aligned          __not_aligned               603002      722835
# __alignment_not_unique __alignment_not_unique      485231      802389
#
#                                                SRR8492551  SRR8492553  \
# gene_name              gene_num
# TSPAN6                 ENSG00000000003                  1           3
# TNMD                   ENSG00000000005                  0           0
# DPM1                   ENSG00000000419                 35          51
# SCYL3                  ENSG00000000457                 20          24
# C1orf112               ENSG00000000460                  9          22
# ...                                                   ...         ...
# __no_feature           __no_feature                145438      152853
# __ambiguous            __ambiguous                  64133       70172
# __too_low_aQual        __too_low_aQual              28268       29391
# __not_aligned          __not_aligned               764383      561496
# __alignment_not_unique __alignment_not_unique      376022      305347
#
#                                                SRR8492554  SRR8492643  \
# gene_name              gene_num
# TSPAN6                 ENSG00000000003                  1           1
# TNMD                   ENSG00000000005                  0           1
# DPM1                   ENSG00000000419                 37          80
# SCYL3                  ENSG00000000457                 30          42
# C1orf112               ENSG00000000460                 13          25
# ...                                                   ...         ...
# __no_feature           __no_feature                164413      169283
# __ambiguous            __ambiguous                  80787       87445
# __too_low_aQual        __too_low_aQual              27637       31442
# __not_aligned          __not_aligned               655503      599841
# __alignment_not_unique __alignment_not_unique      409105      400413
#
#                                                SRR8492827  SRR8492545  ...  \
# gene_name              gene_num                                        ...
# TSPAN6                 ENSG00000000003                  2           0  ...
# TNMD                   ENSG00000000005                  2           0  ...
# DPM1                   ENSG00000000419                 38          10  ...
# SCYL3                  ENSG00000000457                 38          11  ...
# C1orf112               ENSG00000000460                 17           2  ...
# ...                                                   ...         ...  ...
# __no_feature           __no_feature                133754       71914  ...
# __ambiguous            __ambiguous                  53705       21261  ...
# __too_low_aQual        __too_low_aQual              27841       15673  ...
# __not_aligned          __not_aligned               655726      629452  ...
# __alignment_not_unique __alignment_not_unique      310053      248377  ...
#
#                                                SRR8492549  SRR8492721  \
# gene_name              gene_num
# TSPAN6                 ENSG00000000003                  0           9
# TNMD                   ENSG00000000005                  0           1
# DPM1                   ENSG00000000419                 15          44
# SCYL3                  ENSG00000000457                  5          30
# C1orf112               ENSG00000000460                  3          11
# ...                                                   ...         ...
# __no_feature           __no_feature                 39794      118337
# __ambiguous            __ambiguous                  54397       35004
# __too_low_aQual        __too_low_aQual               8276       15925
# __not_aligned          __not_aligned               141070      992850
# __alignment_not_unique __alignment_not_unique      149663      402949
#
#                                                SRR8492730  SRR8492574  \
# gene_name              gene_num
# TSPAN6                 ENSG00000000003                  1           3
# TNMD                   ENSG00000000005                  0           0
# DPM1                   ENSG00000000419                  8          25
# SCYL3                  ENSG00000000457                  6          13
# C1orf112               ENSG00000000460                  4           3
# ...                                                   ...         ...
# __no_feature           __no_feature                 68454       91895
# __ambiguous            __ambiguous                  16127       23941
# __too_low_aQual        __too_low_aQual               9596       14121
# __not_aligned          __not_aligned               964326      891487
# __alignment_not_unique __alignment_not_unique      285815      359667
#
#                                                SRR8492614  SRR8492719  \
# gene_name              gene_num
# TSPAN6                 ENSG00000000003                  4           0
# TNMD                   ENSG00000000005                  0           0
# DPM1                   ENSG00000000419                 18          21
# SCYL3                  ENSG00000000457                 18           8
# C1orf112               ENSG00000000460                  8           5
# ...                                                   ...         ...
# __no_feature           __no_feature                156455       59974
# __ambiguous            __ambiguous                  23980       14291
# __too_low_aQual        __too_low_aQual               9030       10680
# __not_aligned          __not_aligned              1792175      999401
# __alignment_not_unique __alignment_not_unique      687462      244593
#
#                                                SRR8492689  SRR8492609  \
# gene_name              gene_num
# TSPAN6                 ENSG00000000003                  1           2
# TNMD                   ENSG00000000005                  0           0
# DPM1                   ENSG00000000419                 23          24
# SCYL3                  ENSG00000000457                  8          13
# C1orf112               ENSG00000000460                  5          11
# ...                                                   ...         ...
# __no_feature           __no_feature                 74107       73665
# __ambiguous            __ambiguous                  19709       25484
# __too_low_aQual        __too_low_aQual              11243       14089
# __not_aligned          __not_aligned              1045953      665409
# __alignment_not_unique __alignment_not_unique      297155      254161
#
#                                                SRR8492613  SRR8492728
# gene_name              gene_num
# TSPAN6                 ENSG00000000003                  1           1
# TNMD                   ENSG00000000005                  0           0
# DPM1                   ENSG00000000419                 15          23
# SCYL3                  ENSG00000000457                 12          15
# C1orf112               ENSG00000000460                  1           7
# ...                                                   ...         ...
# __no_feature           __no_feature                 75118       99426
# __ambiguous            __ambiguous                  19042       22982
# __too_low_aQual        __too_low_aQual              11012       12434
# __not_aligned          __not_aligned               956071     1036568
# __alignment_not_unique __alignment_not_unique      280899      344759
#
# [24915 rows x 60 columns]

# %%
"""epoCts_unstranded.to_csv("remapped_unstranded/epoONLY_htseq-cts_unstrandedTS3_postQC.csv",
                       sep = ",")"""

# %%
clear all
